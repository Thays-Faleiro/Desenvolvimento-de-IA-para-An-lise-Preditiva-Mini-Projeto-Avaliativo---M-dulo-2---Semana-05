# %% [markdown]
# <a href="https://colab.research.google.com/github/Thays-Faleiro/Desenvolvimento-de-IA-para-An-lise-Preditiva-Mini-Projeto-Avaliativo---M-dulo-2---Semana-05/blob/main/notebook_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile requirements.txt
# numpy>=1.21.0
# pandas>=1.3.0
# matplotlib>=3.4.0
# seaborn>=0.11.0
# opencv-python>=4.5.0
# scikit-learn>=1.0.0
# tensorflow>=2.8.0
# Out:
# Overwriting requirements.txt
